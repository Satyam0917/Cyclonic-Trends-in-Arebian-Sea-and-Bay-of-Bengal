# %% [markdown]
# **"Cyclone Trends in Arabian Sea and Bay of Bengal"**
#
# M.Sc.  Agriculture Analytics
#
# Programming for Geodata Processing
#
# Name - **Satyam Jotiram Kumbhar**
#
# Student ID -  **TS90716**
#
# Date of Submission - 18/01/2024

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/Global - area-averaged monthly anomalies - Sea Surface Temperature from reprocessed observations.csv')

# %%
df
# Out:
#            Date   Average Sea Surface Temperature
# 0    15-01-1993                         -0.177995
# 1    15-02-1993                         -0.176136
# 2    15-03-1993                         -0.131704
# 3    15-04-1993                         -0.124919
# 4    15-05-1993                         -0.115371
# ..          ...                               ...
# 343  15-08-2021                          0.217957
# 344  15-09-2021                          0.211087
# 345  15-10-2021                          0.233332
# 346  15-11-2021                          0.254932
# 347  15-12-2021                          0.213522
#
# [348 rows x 2 columns]

# %%
from matplotlib import pyplot as plt

# Assuming 'df' is your DataFrame
df['Date'] = pd.to_datetime(df['Date'], format='%d-%m-%Y')

# Filter the DataFrame to include only data from 15-01-2000 and onwards
df_filtered = df[df['Date'] >= '2000-01-15']

# Plotting the time series data
plt.plot(df_filtered['Date'], df_filtered[' Average Sea Surface Temperature'])
plt.xlabel('Date')
plt.ylabel('Sea Surface Temperature')
plt.title('Sea Surface Temperature Time Series')

# Rotating x-axis tick labels for better visibility
plt.xticks(rotation=45)  # You can adjust the rotation angle as needed

# Display the plot
plt.show()

# %%
frequency_data = pd.read_csv('/content/Annual_Frequency_1982_2023.csv')

# %%
frequency_data
# Out:
#     Year  Cyclonic Disturbances - BOB  Cyclonic Disturbances - AS  \
# 0   1982                           12                           5
# 1   1983                            4                           1
# 2   1984                            5                           2
# 3   1985                           11                           2
# 4   1986                            5                           1
# 5   1987                            6                           0
# 6   1988                            8                           1
# 7   1989                            9                           1
# 8   1990                            8                           1
# 9   1991                            8                           0
# 10  1992                            8                           4
# 11  1993                            4                           1
# 12  1994                            6                           2
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv('/content/Annual_Frequency_1982_2023.csv')

# Convert 'Year' column to datetime format
df['Year'] = pd.to_datetime(df['Year'], format='%Y')

# Set 'Year' as the index for time series analysis
df.set_index('Year', inplace=True)

import matplotlib.pyplot as plt

# Selecting relevant columns for plotting
df_plot = df[['Cyclones - BOB', 'Severe Cyclones - BOB', 'Cyclones - AS', 'Severe Cyclones - AS']]

# Stacked bar chart
df_plot.plot(kind='bar', stacked=True, figsize=(12, 6))
plt.title('Cyclone Intensity Over Time (Stacked Bar Chart)')
plt.xlabel('Year')
plt.ylabel('Number of Cyclones')
plt.legend(title='Cyclone Type')
plt.show()

# %%
import pandas as pd

# Assuming 'your_data.csv' is the name of your dataset file
file_path = '/content/AS_Cyclones_1982_2023.csv'

# Load the dataset into a pandas DataFrame
df = pd.read_csv(file_path)

# Filter entries where Time (UTC) is 1200
df_1200 = df[df['Time (UTC)'] == 1200]

# Sort the DataFrame based on Maximum Sustained Surface speed (kt)
sorted_df = df_1200.sort_values(by='Estimated Maximum Sustained Surface speed (kt)', ascending=False)

# Display the sorted DataFrame
sorted_df
# Out:
#        Cyclone        Date  Time (UTC)  Lat.  Long. C.I. NO.  \
# 811      KYAAR  27.10.2019        1200  17.5   66.7      6.5
# 819      KYAAR  28.10.2019        1200  18.5   64.3      6.5
# 327       GONU  04.06.2007        1200  20.0   64.0        6
# 205     A.99.1  22.05.1999        1200  27.5   72.0      5.5
# 200     A.99.1  21.05.1999        1200  25.5   70.0      5.5
# ...        ...         ...         ...   ...    ...      ...
# 600     MEKUNU  21.05.2018        1200   8.5   58.5      1.5
# 642      LUBAN  06.10.2018        1200  11.3   66.9      1.5
# 1127  BIPARJOY  18.06.2023        1200  26.3   74.7        .
# 763       VAYU  17.06.2019        1200  22.5   67.8      1.5
# 859      KYAAR  02.11.2019        1200  12.5   53.0      1.5
#
#       Estimated Central Pressure (hPa)  \
# 811                                922
# 819                                928
# 327                                934
# 205                                946
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

# Assuming 'your_data.csv' is the name of your dataset file
file_path = '/content/BOB_Cyclones_1982_2023.csv'

# Load the dataset into a pandas DataFrame
df = pd.read_csv(file_path)

# Convert the 'date' column to datetime format, letting pandas infer the format
df['date'] = pd.to_datetime(df['date'], errors='coerce')

# Filter entries where Time (UTC) is 1200
df_1200 = df[df['Time (UTC)'] == 1200]

# Sort the DataFrame based on Cyclone and Date in ascending order
sorted_df = df_1200.sort_values(by=['Cyclone', 'date'])

# Sort the DataFrame based on index in ascending order
sorted_df = sorted_df.sort_index()

# Display the sorted DataFrame
pd.set_option("display.max_rows", None, "display.max_columns", None)
sorted_df
# Out:
# <ipython-input-12-cb7039ff04f8>:12: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df['date'] = pd.to_datetime(df['date'], errors='coerce')
#       Cyclone       date  Time (UTC)       Lat.      Long. C.I. NO.  \
# 2      B.82.1 1982-01-05        1200         15       82.7      2.5
# 7      B.82.1 1982-02-05        1200       16.5      82.12      3.5
# 12     B.82.1 1982-03-05        1200       17.5      82.17        5
# 17     B.82.1 1982-04-05        1200       17.5      82.22        6
# 20     B.82.2 1982-05-31        1200       14.5      82.25      1.5
# 25     B.82.2 1982-01-06        1200       16.5       82.3      2.5
# 30     B.82.2 1982-02-06        1200         18      82.35        3
# 36     B.82.2 1982-03-06        1200         20      82.41        5
# 41     B.82.2 1982-04-06        1200         23      82.46        2
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'your_data.csv' is the name of your dataset file
file_path = '/content/BOB_Cyclones_1982_2023.csv'

# Load the dataset into a pandas DataFrame
df = pd.read_csv(file_path)

# Convert the 'date' column to datetime format, letting pandas infer the format
df['date'] = pd.to_datetime(df['date'], errors='coerce')

# Filter entries where Time (UTC) is 1200
df_1200 = df[df['Time (UTC)'] == 1200]

# Sort the DataFrame based on Cyclone and Date in ascending order
sorted_df = df_1200.sort_values(by=['Cyclone', 'date'])

# Sort the DataFrame based on index in ascending order
sorted_df = sorted_df.sort_index()

# Display the sorted DataFrame
pd.set_option("display.max_rows", None, "display.max_columns", None)

# Plotting a horizontal bar graph
plt.figure(figsize=(12, 8))

# Assign different colors based on the index
colors = ['red' if i < 449 else 'blue' for i in sorted_df.index]

plt.barh(sorted_df['Cyclone'], sorted_df['Estimated Maximum Sustained Surface speed (kt)'], color=colors)

# Adding labels and title
plt.xlabel('Intensity (kt)')
plt.ylabel('Cyclones and Severe Cyclones in Bay of Bengal')

# Add legends
red_patch = plt.Line2D([0], [0], marker='o', color='w', label='Cyclones before 2001', markerfacecolor='red', markersize=10)
blue_patch = plt.Line2D([0], [0], marker='o', color='w', label='Cyclones after 2001', markerfacecolor='blue', markersize=10)

plt.legend(handles=[red_patch, blue_patch])

plt.show()
# Out:
# <ipython-input-13-d6495cc008c2>:11: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df['date'] = pd.to_datetime(df['date'], errors='coerce')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'your_data.csv' is the name of your dataset file
file_path = '/content/AS_Cyclones_1982_2023.csv'

# Load the dataset into a pandas DataFrame
df = pd.read_csv(file_path)

# Convert the 'date' column to datetime format, letting pandas infer the format
df['Date'] = pd.to_datetime(df['Date'], errors='coerce')

# Filter entries where Time (UTC) is 1200
df_1200 = df[df['Time (UTC)'] == 1200]

# Sort the DataFrame based on Cyclone and Date in ascending order
sorted_df = df_1200.sort_values(by=['Cyclone', 'Date'])

# Sort the DataFrame based on index in ascending order
sorted_df = sorted_df.sort_index()
sorted_df
# Out:
# <ipython-input-15-f91da808567e>:11: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'], errors='coerce')
#        Cyclone       Date  Time (UTC)  Lat.  Long. C.I. NO.  \
# 0       A.82.1 1982-04-11        1200  11.5   66.0      1.5
# 3       A.82.1 1982-05-11        1200  13.0   65.0      2.5
# 6       A.82.1 1982-06-11        1200  14.5   66.0      3.5
# 8       A.82.1 1982-07-11        1200  16.5   67.5        4
# 10      A.82.1 1982-08-11        1200  20.5   70.5        5
# 13      A.82.1 1982-09-11        1200  23.5   75.0      5.3
# 16      A.93.1 1993-12-11        1200  14.0   67.5        2
# 21      A.93.1 1993-11-13        1200  17.5   64.5        3
# 26      A.93.1 1993-11-14        1200  20.5   64.5        4
# 31      A.93.1 1993-11-15        1200  23.5   67.5        3
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'your_data.csv' is the name of your dataset file
file_path = '/content/AS_Cyclones_1982_2023.csv'

# Load the dataset into a pandas DataFrame
df = pd.read_csv(file_path)

# Convert the 'date' column to datetime format, letting pandas infer the format
df['Date'] = pd.to_datetime(df['Date'], errors='coerce')

# Filter entries where Time (UTC) is 1200
df_1200 = df[df['Time (UTC)'] == 1200]

# Sort the DataFrame based on Cyclone and Date in ascending order
sorted_df = df_1200.sort_values(by=['Cyclone', 'Date'])

# Sort the DataFrame based on index in ascending order
sorted_df = sorted_df.sort_index()

# Display the sorted DataFrame
pd.set_option("display.max_rows", None, "display.max_columns", None)

# Plotting a horizontal bar graph
plt.figure(figsize=(12, 8))

# Assign different colors based on the index
colors = ['red' if i < 210 else 'blue' for i in sorted_df.index]

plt.barh(sorted_df['Cyclone'], sorted_df['Estimated Maximum Sustained Surface speed (kt)'], color=colors)

# Adding labels and title
plt.xlabel('Intensity (kt)')
plt.ylabel('Cyclones and Severe Cyclones in Arebian Sea')

# Add legends
red_patch = plt.Line2D([0], [0], marker='o', color='w', label='Cyclones before 2001', markerfacecolor='red', markersize=10)
blue_patch = plt.Line2D([0], [0], marker='o', color='w', label='Cyclones after 2001', markerfacecolor='blue', markersize=10)

plt.legend(handles=[red_patch, blue_patch])

plt.show()
# Out:
# <ipython-input-14-425afb6d8e87>:11: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'], errors='coerce')
